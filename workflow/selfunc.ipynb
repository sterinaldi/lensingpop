# %%
import numpy as np
import matplotlib.pyplot as plt
import dill

# %%
with open('./detectability/selfunc_m1qz_source.pkl', "rb") as f:
    selfun = dill.load(f)
    
with open('./detectability/snr_m1qz_source.pkl', "rb") as f:
    snrfun = dill.load(f)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate input data
x = np.linspace(5,99, 200)
y = np.linspace(0.1,1, 200)
X, Y = np.meshgrid(x, y)
Z = selfun(np.array([X.flatten(), Y.flatten(), 0.1*np.ones(X.flatten().shape)]).T)
 
# Plotting in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

scatter1 = ax.scatter(X.ravel(), Y.ravel(), Z1, c=Z, cmap='viridis', label='f(x, y)', marker='o')
cbar = fig.colorbar(scatter1, ax=ax, shrink=0.5, aspect=5)
cbar.set_label(r'$p_\mathrm{det}$')

# Customize labels and title
ax.set_xlabel(r'$m_1^z$')
ax.set_ylabel(r'$q$')
ax.set_zlabel(r'$p_\mathrm{det}$')
ax.set_title(r'$z=0.1$')

# Add a color bar which maps values to colors

plt.show()

# %%
Z = selfun(np.array([X.flatten(), Y.flatten(), 0.8*np.ones(X.flatten().shape)]).T)
 
# Plotting in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

scatter1 = ax.scatter(X.ravel(), Y.ravel(), Z, c=Z, cmap='viridis', label='f(x, y)', marker='o')
cbar = fig.colorbar(scatter1, ax=ax, shrink=0.5, aspect=5)
cbar.set_label(r'$p_\mathrm{det}$')

# Customize labels and title
ax.set_xlabel(r'$m_1^z$')
ax.set_ylabel(r'$q$')
ax.set_zlabel(r'$p_\mathrm{det}$')
ax.set_title(r'$z=0.8$')
plt.show()
